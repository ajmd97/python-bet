# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# def obtener_analisis(soup):
#     list_analisis = []
    
#     # ahora vamos a buscar "analisis" en toda la lista de matches, por lo tanto tenemos que poner de nuevo el código de búsqueda
#     r_analisis = requests.get(soup)
#     s_analisis = BeautifulSoup(r_analisis.text, 'lxml')
#     find_analisis = s_analisis.find('div', attrs={'class':'menu-scroll'}).select('a[href*="analisis"]')
#     analisis = find_analisis[0]
#     if analisis:
#         list_analisis.append(analisis.get('href'))
        
#     return list_analisis

# %%
def obtener_stats(func_stats):
    stats_dict = {}
    
    date = func_stats.find('div', attrs={'class':'info match-link'})
    if date:
        stats_dict['date'] = date.get('starttime').replace('T',' ').replace(':00+00:00','')
    else:
        stats_dict['date'] = '-'
 
    draw = func_stats.find('div', attrs={'class':'content-box draw'}).find('div', attrs={'class':'cont'})
    if draw:
        stats_dict['draw'] = draw.get_text('/',strip=True).replace('%','')[4:10]
    else:
        stats_dict['draw'] = '-' 
        
    homeRank = func_stats.find('div', attrs={'class':'position t1'})
    if homeRank:
        stats_dict['homeRank'] = homeRank.get_text()
    else:
        stats_dict['homeRank'] = '-'    
            
    homeTeam = func_stats.find('p', attrs={'itemprop':'homeTeam'})
    if homeTeam:
        stats_dict['homeTeam'] = homeTeam.get_text('/', strip=True)
    else:
        stats_dict['homeTeam'] = '-'

    homeGoals = func_stats.find('div', attrs={'class':'content-box t-1'}).find('div', attrs={'class':'poss-box'})
    if homeGoals:
        stats_dict['homeGoals'] = homeGoals.get_text('/', strip=True).replace('/Probabilidad gana/',' - ').replace('/Goles esperados','')
    else:
        stats_dict['homeGoals'] = '-'     
        
    awayGoals = func_stats.find('div', attrs={'class':'content-box t-2'}).find('div', attrs={'class':'poss-box'})
    if awayGoals:
        stats_dict['awayGoals'] = awayGoals.get_text('/', strip=True).replace('/Probabilidad gana/',' - ').replace('/Goles esperados','')
    else:
        stats_dict['awayGoals'] = '-'     

    awayTeam = func_stats.find('p', attrs={'itemprop':'awayTeam'})
    if awayTeam:
        stats_dict['awayTeam'] = awayTeam.get_text('/', strip=True)
    else:
        stats_dict['awayTeam'] = '-'     
     
    awayRank = func_stats.find('div', attrs={'class':'position t2'})
    if awayRank:
        stats_dict['awayRank'] = awayRank.get_text()
    else:
        stats_dict['awayRank'] = '-' 
        
    competition = func_stats.find('h3', attrs={'class':'competition'})
    if competition:
        stats_dict['competition'] = competition.get_text('/', strip=True)
    else:
        stats_dict['competition'] = '-'
   
    return stats_dict

# %%
df = pd.DataFrame()

# %%
url = input('Introduce la url a scrapear: ')
#url = 'https://es.besoccer.com/livescore/2022-09-21'
besoccer = requests.get(url)

# por ejemplo: https://es.besoccer.com/livescore/2022-09-20
# Out:
# Introduce la url a scrapear: https://es.besoccer.com/livescore/2022-09-22/3

# %%
besoccer.status_code
# Out:
# 200

# %%
s_besoccer = BeautifulSoup(besoccer.text, 'lxml')

# %%
matches = s_besoccer.find('div', attrs={'class':'matches'}).select('a[href*="/partido/"]')

# %%
[match.text for match in matches]
# Out:
# ['\n\n\n\nJornada 13\n\n\n\n\nTurquia Sub 18\n\n\n\n16:30\n\n\n\nRumania Sub 18\n\n22 sep 2022\n',
#  '\n\n\n\nGran Canaria - G2. J 2\n\n\n\n\nCasa Pastores\n\n\n\n22:00\n\n\n\nCalero\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 28\n\n\n\n\nAmérica Quito\n\n\n\n02:00\n\n\n\nManta\n\n22 sep 2022\n',
#  '\n\n\n\nGrupo 3. J 22\n\n\n\n\nViking FK II\n\n\n\n14:00\n\n\n\nHaugesund II\n\n22 sep 2022\n',
#  '\n\n\n\nGrupo 3. J 22\n\n\n\n\nSola Fotball\n\n\n\n17:30\n\n\n\nVidar\n\n22 sep 2022\n',
#  '\n\n\n\nGrupo 6. J 22\n\n\n\n\nFløya\n\n\n\n20:00\n\n\n\nSkjervøy\n\n22 sep 2022\n',
#  '\n\n\n\nTemporada Regular. J 6\n\n\n\n\nHapoel Nof HaGalil\n\n\n\n18:30\n\n\n\nHapoel Rishon Lezion\n\n22 sep 2022\n',
#  '\n\n\n\nTemporada Regular. J 6\n\n\n\n\nHapoel Kfar Saba\n\n\n\n18:30\n\n\n\nKafr Qasim\n\n22 sep 2022\n',
#  '\n\n\n\nTemporada Regular. J 6\n\n\n\n\nMaccabi Ahi Nazareth\n\n\n\n18:30\n\n\n\nHapoel Nir Ramat HaSharon\n\n22 sep 2022\n',
#  '\n\n\n\nTemporada Regular. J 6\n\n\n\n\nIroni Tiberias\n\n\n\n18:30\n\n\n\nHapoel Ramat Gan\n\n22 sep 2022\n',
#  '\n\n\n\nTemporada Regular. J 6\n\n\n\n\nHapoel Acre\n\n\n\n18:30\n\n\n\nMaccabi Kabilio Jaffa\n\n22 sep 2022\n',
#  '\n\n\n\nEtapas Finales. Final\n\n\n\n\nCriciuma\n\n\n\n01:00\n\n\n\nAtletico Catarinense\n\n21 sep 2022\n',
#  '\n\n\n\nJornada 13\n\n\n\n\nPuebla\n\n\n\n23:00\n\n\n\nLeón\n\n22 sep 2022\n',
#  '\n\n\n\nEtelä. J 35\n\n\n\n\nPonnistajat\n\n\n\n19:00\n\n\n\nAtlantis II\n\n22 sep 2022\n',
#  '\n\n\n\nEtapas Finales. Semi.\n\n\n\n\nMaranhão\n\n\n\n20:30\n\n\n\nSabiá Fc\n\n22 sep 2022\n',
#  '\n\n\n\n2ª Fase. J 3\n\n\n\n\nIndpendiente Simao Dias\n\n\n\n20:00\n\n\n\nBoquinhense\n\n22 sep 2022\n',
#  '\n\n\n\n2ª Fase. J 3\n\n\n\n\nRosario Central SE\n\n\n\n20:00\n\n\n\nSocorrense\n\n22 sep 2022\n',
#  '\n\n\n\n1ª Fase. J 2\n\n\n\n\nGrêmio B\n\n\n\n20:00\n\n\n\n12 Horas\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 3\n\n\n\n\nAccra Lions FC\n\n\n\n16:00\n\n\n\nTamale City\n\n22 sep 2022\n',
#  '\n\n\n\nFase de Grupos. J 3\n\n\n\n\nMageense\n\n\n\n20:00\n\n\n\nBarra da Tijuca\n\n22 sep 2022\n',
#  '\n\n\n\nFase de Grupos. J 3\n\n\n\n\nTigres do Brasil\n\n\n\n20:00\n\n\n\nCarapebus EC\n\n22 sep 2022\n',
#  '\n\n\n\nApl\n\n\nFase de Grupos. J 3\n\n\n\n\nGoytacaz\n\n\n\n20:00\n\n\n\nCéres\n\n22 sep 2022\n',
#  '\n\n\n\nFase de Grupos. J 3\n\n\n\n\nArmação dos Búzios\n\n\n\n20:00\n\n\n\nBarra Mansa\n\n22 sep 2022\n',
#  '\n\n\n\nFase de Grupos. J 3\n\n\n\n\nCampos AA\n\n\n\n20:00\n\n\n\nRio de Janeiro\n\n22 sep 2022\n',
#  '\n\n\n\nFase de Grupos. J 3\n\n\n\n\nBonsucesso\n\n\n\n20:00\n\n\n\nBelford Roxo\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 1\n\n\n\n\nBrondby Reservas\n\n\n\n15:00\n\n\n\nAGF Aarhus Reservas\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nBaBel United\n\n\n\n09:15\n\n\n\nPSBS Biak Numfor\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nPSKC Cimahi\n\n\n\n10:15\n\n\n\nKaro United\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nDeltras\n\n\n\n10:15\n\n\n\nSulut United\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nSriwijaya\n\n\n\n10:30\n\n\n\nPersiraja Banda Aceh\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nPersela\n\n\n\n10:30\n\n\n\nPersipa Pati\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nPSPS Pekanbaru\n\n\n\n11:00\n\n\n\nPSMS Medan\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nSemen Padang\n\n\n\n11:00\n\n\n\nPerserang\n\n22 sep 2022\n',
#  '\n\n\n\n1ra Ronda. J 5\n\n\n\n\nPersiba Balikpapan\n\n\n\n13:15\n\n\n\nKalteng Putra\n\n22 sep 2022\n',
#  '\n\n\n\nOeste/Sur. J 21\n\n\n\n\nAjax Lasnamäe\n\n\n\n18:00\n\n\n\nHiiumaa\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 7\n\n\n\n\nBujumbura City\n\n\n\n15:00\n\n\n\nOlympic Star\n\n22 sep 2022\n',
#  '\n\n\n\nTemporada Regular. J 6\n\n\n\n\nKasetsart\n\n\n\n12:30\n\n\n\nRanong\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 4\n\n\n\n\nCe Campanet\n\n\n\n20:30\n\n\n\nMontaura\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 1\n\n\n\n\nMalvarrosa A\n\n\n\n20:30\n\n\n\nFonteta B\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 2\n\n\n\n\nCD Algeteño\n\n\n\n20:00\n\n\n\nValdetorres\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 3\n\n\n\n\nParo FC\n\n\n\n11:00\n\n\n\nParo Rinpung\n\n22 sep 2022\n',
#  '\n\n\n\nJornada 1\n\n\n\n\nSaint-Georges\n\n\n\n01:00\n\n\n\nEtoile Matoury\n\n21 sep 2022\n']

# %%
try:
    match = matches[0]
    match.get('href')
except Exception as e:
    print('No hay más partidos que analizar')

# %%
links_matches = [match.get('href') for match in matches]

# %%
for i in range(len(links_matches)):
    list_analisis = []
    r_match = requests.get(links_matches[i])
    s_match = BeautifulSoup(r_match.text, 'lxml')
    find_analisis = s_match.find('div', attrs={'class':'menu-scroll'}).select('a[href*="analisis"]')
    try:
        analisis = find_analisis[0]
        link_analisis = analisis.get('href')
        r_link_analisis = requests.get(link_analisis)
        s_link_analisis = BeautifulSoup(r_link_analisis.text, 'lxml')
        df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
        print(i, link_analisis)
    except Exception as e:
        print(i,'.- La url ',links_matches[i],' no tiene sección análisis')
        print(i,'.-',e)
# Out:
# 0 .- La url  https://es.besoccer.com/partido/turquia-sub-18/seleccion-rumania-sub18/2022583619  no tiene sección análisis
# 0 .- list index out of range
# 1 .- La url  https://es.besoccer.com/partido/cf-casa-pastores-senior/cd-calero-senior/2023426204  no tiene sección análisis
# 1 .- list index out of range
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 2 https://es.besoccer.com/partido/america-quito/manta/2022420568/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 3 https://es.besoccer.com/partido/viking-2/haugesund-ii/2022317462/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 4 https://es.besoccer.com/partido/sola-fotball/vidar/2022317461/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 5 https://es.besoccer.com/partido/floya/skjervoy-ik/2022316908/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 6 https://es.besoccer.com/partido/hapoel-natzrat-elite/hapoel-rishon-lezion/202310733/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 7 https://es.besoccer.com/partido/hapoel-kfar-saba/hapoel-kafr-qasim-shouaa/202310728/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 8 https://es.besoccer.com/partido/maccabi-ahi-nazrat/hapoel-nir-ramat-hasharon/202310734/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 9 https://es.besoccer.com/partido/ironi-tiberias/hapoel-ramat-gan/202310732/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 10 https://es.besoccer.com/partido/hapoel-acre/maccabi-kabilio-jaffa/202310727/analisis
# 11 .- La url  https://es.besoccer.com/partido/criciuma-ec/atletico-catarinens/2022545289  no tiene sección análisis
# 11 .- list index out of range
# 12 .- La url  https://es.besoccer.com/partido/puebla-femenino/club-leon-femenino/202313726  no tiene sección análisis
# 12 .- list index out of range
# 13 .- La url  https://es.besoccer.com/partido/ponnistajat/atlantis-ii/2022338793  no tiene sección análisis
# 13 .- list index out of range
# 14 .- La url  https://es.besoccer.com/partido/maranhao/sabia-fc/2022596303  no tiene sección análisis
# 14 .- list index out of range
# 15 .- La url  https://es.besoccer.com/partido/independiente-simao-dias/boquinhense/2022577155  no tiene sección análisis
# 15 .- list index out of range
# 16 .- La url  https://es.besoccer.com/partido/rosario-central-sergipano/socorrense/2022577156  no tiene sección análisis
# 16 .- list index out of range
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 17 https://es.besoccer.com/partido/gremio-b/sc-doce-horas/2022574053/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 18 https://es.besoccer.com/partido/accra-lions/tamale-city/2023386347/analisis
# 19 .- La url  https://es.besoccer.com/partido/mageense-fc/barra-da-tijuca/2023376881  no tiene sección análisis
# 19 .- list index out of range
# 20 .- La url  https://es.besoccer.com/partido/tigres-do-brasil/carapebus-ec/2023376882  no tiene sección análisis
# 20 .- list index out of range
# 21 .- La url  https://es.besoccer.com/partido/goytacaz/ceres/2023376883  no tiene sección análisis
# 21 .- list index out of range
# 22 .- La url  https://es.besoccer.com/partido/Armaçao/barra-mansa/2023376884  no tiene sección análisis
# 22 .- list index out of range
# 23 .- La url  https://es.besoccer.com/partido/campos-atletico-associacao/rio-de-janeiro-fc/2023376885  no tiene sección análisis
# 23 .- list index out of range
# 24 .- La url  https://es.besoccer.com/partido/bonsucesso/belford-roxo/2023376886  no tiene sección análisis
# 24 .- list index out of range
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 25 https://es.besoccer.com/partido/brondby-reservas/agf-aarhus-reservas/2023333983/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 26 https://es.besoccer.com/partido/bangka-belitung-united-fc/persatuan-sepakbola-biak-sekitarnya/2022542010/analisis
# 27 .- La url  https://es.besoccer.com/partido/pskc-cimahi-city/karo-united-fc/2022542001  no tiene sección análisis
# 27 .- 'NoneType' object has no attribute 'find'
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 28 https://es.besoccer.com/partido/deltras/sulut-united-fc/2022542213/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 29 https://es.besoccer.com/partido/sriwijaya/persatuan-sepakbola-persiraja-banda-acel/2022542002/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 30 https://es.besoccer.com/partido/persela/persatuan-sepakbola-indonesia-pati/2022542005/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 31 https://es.besoccer.com/partido/psps-pekanbaru/psms-medan/2022542003/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 32 https://es.besoccer.com/partido/semen/perserang-serang/2022542004/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 33 https://es.besoccer.com/partido/persiba-balikpapan/kalteng-putra/2022542012/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 34 https://es.besoccer.com/partido/ajax-lasnamae/hiiumaa/2022437842/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 35 https://es.besoccer.com/partido/bujumbura-city/olympic-star/2023329060/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 36 https://es.besoccer.com/partido/kasetsart-fc/ranong/202399046/analisis
# 37 .- La url  https://es.besoccer.com/partido/ce-campanet-senior/montaura/2023420436  no tiene sección análisis
# 37 .- list index out of range
# 38 .- La url  https://es.besoccer.com/partido/cf-malvarrosa-a-senior/ud-fonteta-b/2023436582  no tiene sección análisis
# 38 .- list index out of range
# 39 .- La url  https://es.besoccer.com/partido/cd-algeteno-senior/valdetorres/2023437371  no tiene sección análisis
# 39 .- list index out of range
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)
# 40 https://es.besoccer.com/partido/paro-fc/paro-rinpung-fc/2022529239/analisis
# 41 https://es.besoccer.com/partido/saint-georges-cayenne/as-etoile-matoury/2023442660/analisis
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18036\483865442.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(obtener_stats(s_link_analisis), ignore_index = True)

# %%
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_61000_row0_col0, #T_61000_row0_col1, #T_61000_row0_col2, #T_61000_row0_col3, #T_61000_row0_col4, #T_61000_row0_col5, #T_61000_row0_col6, #T_61000_row0_col7, #T_61000_row0_col8, #T_61000_row1_col0, #T_61000_row1_col1, #T_61000_row1_col2, #T_61000_row1_col3, #T_61000_row1_col4, #T_61000_row1_col5, #T_61000_row1_col6, #T_61000_row1_col7, #T_61000_row1_col8, #T_61000_row2_col0, #T_61000_row2_col1, #T_61000_row2_col2, #T_61000_row2_col3, #T_61000_row2_col4, #T_61000_row2_col5, #T_61000_row2_col6, #T_61000_row2_col7, #T_61000_row2_col8, #T_61000_row3_col0, #T_61000_row3_col1, #T_61000_row3_col2, #T_61000_row3_col3, #T_61000_row3_col4, #T_61000_row3_col5, #T_61000_row3_col6, #T_61000_row3_col7, #T_61000_row3_col8, #T_61000_row4_col0, #T_61000_row4_col1, #T_61000_row4_col2, #T_61000_row4_col3, #T_61000_row4_col4, #T_61000_row4_col5, #T_61000_row4_col6, #T_61000_row4_col7, #T_61000_row4_col8, #T_61000_row5_col0, #T_61000_row5_col1, #T_61000_row5_col2, #T_61000_row5_col3, #T_61000_row5_col4, #T_61000_row5_col5, #T_61000_row5_col6, #T_61000_row5_col7, #T_61000_row5_col8, #T_61000_row6_col0, #T_61000_row6_col1, #T_61000_row6_col2, #T_61000_row6_col3, #T_61000_row6_col4, #T_61000_row6_col5, #T_61000_row6_col6, #T_61000_row6_col7, #T_61000_row6_col8, #T_61000_row7_col0, #T_61000_row7_col1, #T_61000_row7_col2, #T_61000_row7_col3, #T_61000_row7_col4, #T_61000_row7_col5, #T_61000_row7_col6, #T_61000_row7_col7, #T_61000_row7_col8, #T_61000_row8_col0, #T_61000_row8_col1, #T_61000_row8_col2, #T_61000_row8_col3, #T_61000_row8_col4, #T_61000_row8_col5, #T_61000_row8_col6, #T_61000_row8_col7, #T_61000_row8_col8, #T_61000_row9_col0, #T_61000_row9_col1, #T_61000_row9_col2, #T_61000_row9_col3, #T_61000_row9_col4, #T_61000_row9_col5, #T_61000_row9_col6, #T_61000_row9_col7, #T_61000_row9_col8, #T_61000_row10_col0, #T_61000_row10_col1, #T_61000_row10_col2, #T_61000_row10_col3, #T_61000_row10_col4, #T_61000_row10_col5, #T_61000_row10_col6, #T_61000_row10_col7, #T_61000_row10_col8, #T_61000_row11_col0, #T_61000_row11_col1, #T_61000_row11_col2, #T_61000_row11_col3, #T_61000_row11_col4, #T_61000_row11_col5, #T_61000_row11_col6, #T_61000_row11_col7, #T_61000_row11_col8, #T_61000_row12_col0, #T_61000_row12_col1, #T_61000_row12_col2, #T_61000_row12_col3, #T_61000_row12_col4, #T_61000_row12_col5, #T_61000_row12_col6, #T_61000_row12_col7, #T_61000_row12_col8, #T_61000_row13_col0, #T_61000_row13_col1, #T_61000_row13_col2, #T_61000_row13_col3, #T_61000_row13_col4, #T_61000_row13_col5, #T_61000_row13_col6, #T_61000_row13_col7, #T_61000_row13_col8, #T_61000_row14_col0, #T_61000_row14_col1, #T_61000_row14_col2, #T_61000_row14_col3, #T_61000_row14_col4, #T_61000_row14_col5, #T_61000_row14_col6, #T_61000_row14_col7, #T_61000_row14_col8, #T_61000_row15_col0, #T_61000_row15_col1, #T_61000_row15_col2, #T_61000_row15_col3, #T_61000_row15_col4, #T_61000_row15_col5, #T_61000_row15_col6, #T_61000_row15_col7, #T_61000_row15_col8, #T_61000_row16_col0, #T_61000_row16_col1, #T_61000_row16_col2, #T_61000_row16_col3, #T_61000_row16_col4, #T_61000_row16_col5, #T_61000_row16_col6, #T_61000_row16_col7, #T_61000_row16_col8, #T_61000_row17_col0, #T_61000_row17_col1, #T_61000_row17_col2, #T_61000_row17_col3, #T_61000_row17_col4, #T_61000_row17_col5, #T_61000_row17_col6, #T_61000_row17_col7, #T_61000_row17_col8, #T_61000_row18_col0, #T_61000_row18_col1, #T_61000_row18_col2, #T_61000_row18_col3, #T_61000_row18_col4, #T_61000_row18_col5, #T_61000_row18_col6, #T_61000_row18_col7, #T_61000_row18_col8, #T_61000_row19_col0, #T_61000_row19_col1, #T_61000_row19_col2, #T_61000_row19_col3, #T_61000_row19_col4, #T_61000_row19_col5, #T_61000_row19_col6, #T_61000_row19_col7, #T_61000_row19_col8, #T_61000_row20_col0, #T_61000_row20_col1, #T_61000_row20_col2, #T_61000_row20_col3, #T_61000_row20_col4, #T_61000_row20_col5, #T_61000_row20_col6, #T_61000_row20_col7, #T_61000_row20_col8, #T_61000_row21_col0, #T_61000_row21_col1, #T_61000_row21_col2, #T_61000_row21_col3, #T_61000_row21_col4, #T_61000_row21_c ...

# %%
df.to_csv('matches.csv', header = False)
